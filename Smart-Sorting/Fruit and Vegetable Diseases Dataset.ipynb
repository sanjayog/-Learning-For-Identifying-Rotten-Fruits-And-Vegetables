# %%
import zipfile
import os

zip_path = 'archive.zip'  # must match the file name exactly
extract_to = 'dataset'

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("✅ Dataset unzipped successfully.")
# Out:
# ✅ Dataset unzipped successfully.

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
base_dir = 'fruits-vegetables-dataset'  # or wherever your unzipped folder is
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'validation')

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Load the VGG16 base model without the top layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random

dataset_dir = "dataset/Fruit And Vegetable Diseases Dataset"
class_names = [d for d in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, d))]
random_class = random.choice(class_names)
class_path = os.path.join(dataset_dir, random_class)

# Filter only image files (e.g., .jpg, .jpeg, .png)
image_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Take first 5 images
sample_images = image_files[:5]

# Display them
plt.figure(figsize=(12, 4))
for i, img_file in enumerate(sample_images):
    img_path = os.path.join(class_path, img_file)
    img = mpimg.imread(img_path)
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(random_class, fontsize=8)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random

dataset_dir = "dataset/Fruit And Vegetable Diseases Dataset"
class_names = [d for d in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, d))]
random_class = random.choice(class_names)
class_path = os.path.join(dataset_dir, random_class)

# Filter only image files (e.g., .jpg, .jpeg, .png)
image_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Take first 5 images
sample_images = image_files[:5]

# Display them
plt.figure(figsize=(12, 4))
for i, img_file in enumerate(sample_images):
    img_path = os.path.join(class_path, img_file)
    img = mpimg.imread(img_path)
    plt.subplot(1, 5, i + 1)
    plt.imshow(img)
    plt.title(random_class, fontsize=8)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Load the VGG16 base model without the top layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

# Create the full model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.2857 - loss: 1.4293
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3571 - loss: 1.3197
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5714 - loss: 1.1769
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.5000 - loss: 1.0731
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3571 - loss: 1.0836
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.2857 - loss: 1.0041
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3571 - loss: 1.0445
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.3571 - loss: 1.1691
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.5000 - loss: 1.0756
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.4286 - loss: 1.0756

# %%
train_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
val_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# %%
import os

print(os.path.exists(train_dir))  # Should print: True
print(os.path.exists(val_dir))    # Should print: True
# Out:
# True
# True

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 5 images belonging to 2 classes.
# Found 2 images belonging to 2 classes.

# %%
import os

for root, dirs, files in os.walk("C:\\Users"):
    if "Fruit and Vegetable Diseases Dataset" in root:
        print(root)
# Out:
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\Apple__Healthy
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train\Apple__Healthy
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train\train
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation\Apple__Healthy
# C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation\train

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import os

# Define paths
train_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
val_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# Image data generators (no augmentation for now)
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow from directory
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Build model with explicit Input layer
model = Sequential([
    Input(shape=(224, 224, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(64, activation='relu'),
    Dense(train_generator.num_classes, activation='softmax')  # auto-detects number of classes
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Save best model only
checkpoint_cb = ModelCheckpoint("best_model.keras", save_best_only=True)

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=[checkpoint_cb]
)
# Out:
# Found 5 images belonging to 2 classes.
# Found 2 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.6384 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# ...

# %%
# Evaluate on validation set
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Accuracy: {val_accuracy:.4f}, Loss: {val_loss:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Validation Accuracy: 1.0000, Loss: 0.0000

# %%
model.save("final_model.keras")

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Recreate the model architecture
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(28, activation='softmax')  # 28 classes
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Directory paths
train_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
val_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# Image Generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical'
)
val_generator = val_datagen.flow_from_directory(
    val_dir, target_size=(224, 224), batch_size=32, class_mode='categorical'
)

# Load VGG16 base
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(train_generator, validation_data=val_generator, epochs=10)
# Out:
# Found 5 images belonging to 2 classes.
# Found 2 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2000 - loss: 1.0130 - val_accuracy: 1.0000 - val_loss: 0.0591
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0650 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 7.3122e-04
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 6.6839e-04 - val_accuracy: 1.0000 - val_loss: 1.5967e-04
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 4.7146e-05
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.8620e-05 - val_accuracy: 1.0000 - val_loss: 1.7404e-05
# Epoch 7/10
# ...

# %%
# ✅ Import libraries
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# ✅ Set base data path
base_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset"
train_path = os.path.join(base_path, "train")

# ✅ List of classes (folders inside 'train')
classes = os.listdir(train_path)
print("Classes found:", classes)
# Out:
# Classes found: ['.ipynb_checkpoints', 'Apple__Healthy']

# %% [raw]
# class_counts = {cls: len(os.listdir(os.path.join(train_path, cls))) for cls in classes}
#
# plt.figure(figsize=(12, 6))
# plt.bar(class_counts.keys(), class_counts.values(), color='orange')
# plt.xticks(rotation=45, ha='right')
# plt.title("Number of Images in Each Class")
# plt.xlabel("Class Name")
# plt.ylabel("Image Count")
# plt.tight_layout()
# plt.show()

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# ✅ Set base path
train_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
classes = os.listdir(train_path)

# ✅ Filter classes that actually have images
non_empty_classes = [cls for cls in classes if len(os.listdir(os.path.join(train_path, cls))) > 0]

# ✅ Display random images from 6 non-empty class folders
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle("Sample Images from Random Non-Empty Classes", fontsize=16)

for ax in axes.flatten():
    class_name = random.choice(non_empty_classes)
    class_dir = os.path.join(train_path, class_name)
    image_list = os.listdir(class_dir)

    # Double-check again inside loop for safety
    if len(image_list) == 0:
        ax.set_title(f"{class_name} (No images)")
        ax.axis('off')
        continue

    image_file = random.choice(image_list)
    image_path = os.path.join(class_dir, image_file)

    img = mpimg.imread(image_path)
    ax.imshow(img)
    ax.set_title(class_name, fontsize=10)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import os

# Load the trained model (✅ corrected path)
model_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\final_model.keras"
model = load_model(model_path)

# Directory containing standalone images (outside train/validation)
image_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\Apple__Healthy"

# Get the first .jpg image from the folder
image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
if not image_files:
    raise FileNotFoundError("❌ No .jpg images found in the Apple__Healthy folder.")
img_path = os.path.join(image_dir, image_files[0])
print(f"✅ Using image: {img_path}")

# Load and preprocess the image
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict the class
prediction = model.predict(img_array)
predicted_index = np.argmax(prediction[0])

# Load class labels from training folder
train_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
class_labels = sorted(os.listdir(train_dir))  # Assumes each subfolder is a class

# Display the predicted class
predicted_class = class_labels[predicted_index]
print(f"🎯 Predicted Class: {predicted_class}")

# Show the image with prediction
plt.imshow(img)
plt.title(f"Predicted: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# ✅ Using image: C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\Apple__Healthy\FreshApple (1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 🎯 Predicted Class: .ipynb_checkpoints

# %%
train_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
classes = os.listdir(train_path)
print("Available Classes:\n", classes)
# Out:
# Available Classes:
#  ['.ipynb_checkpoints', 'Apple__Healthy']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# ✅ Set the correct dataset path and class name
train_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
specific_class = "Apple__Healthy"  # 👈 this is exactly what your folder is named
specific_class_dir = os.path.join(train_path, specific_class)

# ✅ Get all image files from the class directory
image_list = os.listdir(specific_class_dir)
image_count = min(len(image_list), 6)  # Show up to 6 images (or fewer if less exist)

# ✅ Plot images
fig, axes = plt.subplots(1, image_count, figsize=(15, 5))
fig.suptitle(f"Sample Images from Class: {specific_class}", fontsize=16)

for i in range(image_count):
    image_file = image_list[i]
    image_path = os.path.join(specific_class_dir, image_file)
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
train_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
class_labels = sorted(os.listdir(train_dir))  # Class names = folder names
print("📂 Class Labels:", class_labels)
# Out:
# 📂 Class Labels: ['.ipynb_checkpoints', 'Apple__Healthy']

# %%
trainpath = "/content/output_dataset/train"
testpath = "/content/output_dataset/test"

# %%
# ✅ Import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ✅ Define train and test data generators with rescaling and augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   shear_range=0.2)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# ✅ Use raw strings (r"...") or double backslashes for Windows paths
trainpath = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
testpath = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# ✅ Re-run the ImageDataGenerators if not already done
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.2, shear_range=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# ✅ Load images using flow_from_directory
train = train_datagen.flow_from_directory(trainpath, target_size=(224, 224), batch_size=20)
test = test_datagen.flow_from_directory(testpath, target_size=(224, 224), batch_size=20)
# Out:
# Found 5 images belonging to 2 classes.
# Found 2 images belonging to 2 classes.

# %%
import os
import shutil
import random
from sklearn.model_selection import train_test_split

# ✅ Step 1: Set base dataset folder
base_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset"
source_dir = os.path.join(base_dir, "Apple__Healthy")  # Example class folder to split

# ✅ Step 2: Create output folders
train_class_dir = os.path.join(base_dir, "train", "Apple__Healthy")
val_class_dir = os.path.join(base_dir, "validation", "Apple__Healthy")

os.makedirs(train_class_dir, exist_ok=True)
os.makedirs(val_class_dir, exist_ok=True)

# ✅ Step 3: Get list of image files
all_images = os.listdir(source_dir)
train_images, val_images = train_test_split(all_images, test_size=0.2, random_state=42)

# ✅ Step 4: Move images to train folder
for img in train_images:
    src = os.path.join(source_dir, img)
    dst = os.path.join(train_class_dir, img)
    if os.path.isfile(src):  # Avoid subfolders or non-image files
        shutil.copy2(src, dst)

# ✅ Step 5: Move images to validation folder
for img in val_images:
    src = os.path.join(source_dir, img)
    dst = os.path.join(val_class_dir, img)
    if os.path.isfile(src):
        shutil.copy2(src, dst)

print("✅ Data successfully split into train and validation folders for 'Apple__Healthy'")
# Out:
# ✅ Data successfully split into train and validation folders for 'Apple__Healthy'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam

# ✅ Define number of output classes manually (you can also use train_generator.num_classes if already defined)
num_classes = 4  # Replace 4 with the correct number of classes

# ✅ Define CNN Model using Input() layer (best practice)
model = Sequential([
    Input(shape=(224, 224, 3)),

    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# ✅ Compile model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# ✅ Model Summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 54, 54, 64)          │               0 │
# ...

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# ✅ Re-import required modules
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

# ✅ Set paths
train_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\train"
val_path = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# ✅ Setup data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# ✅ Rebuild model to match the correct number of classes
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Input(shape=(224, 224, 3)),

    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(train_generator.num_classes, activation='softmax')  # 👈 Match number of classes dynamically
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# ✅ Add checkpoint callback
checkpoint_cb = ModelCheckpoint("best_model_part3.keras", save_best_only=True)

# ✅ Train model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[checkpoint_cb]
)
# Out:
# Found 7 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 0.6705 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# ...

# %%
model.save("healthy_vs_rotten_model.keras")

# If you still want to use HDF5 format (.h5), you can do:
# model.save("healthy_vs_rotten_model.h5")  # <- optional, legacy format

print("✅ Model saved successfully as 'healthy_vs_rotten_model.keras'")
# Out:
# ✅ Model saved successfully as 'healthy_vs_rotten_model.keras'

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# ✅ Set validation directory path
val_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset\validation"

# ✅ Get all class labels with non-empty folders
class_labels = [cls for cls in os.listdir(val_dir) 
                if os.path.isdir(os.path.join(val_dir, cls)) and len(os.listdir(os.path.join(val_dir, cls))) > 0]

# ✅ Safely pick a class with images
selected_class = random.choice(class_labels)
class_path = os.path.join(val_dir, selected_class)
img_name = random.choice(os.listdir(class_path))
img_path = os.path.join(class_path, img_name)

# ✅ Load and preprocess image
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) / 255.0

# ✅ Predict
prediction = model.predict(img_array)
predicted_class = class_labels[np.argmax(prediction)]

# ✅ Show image with prediction
plt.imshow(img)
plt.title(f"Predicted: {predicted_class}\nActual: {selected_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step

# %%
import matplotlib.pyplot as plt

# ✅ Evaluate model on validation data
loss, accuracy = model.evaluate(test)
print(f"\nValidation Loss: {loss:.4f}")
print(f"Validation Accuracy: {accuracy:.4f}")

# ✅ Plot training & validation accuracy/loss
plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 244.6796
#
# Validation Loss: 244.6796
# Validation Accuracy: 0.0000

# %%
import matplotlib.pyplot as plt

# ✅ Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# ✅ Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# ✅ Step 12A: Save the model in the recommended Keras format
model.save("fruit_veg_disease_model.keras")
print("✅ Model saved successfully as 'fruit_veg_disease_model.keras'")

# ✅ Step 12B: Load the saved model
loaded_model = load_model("fruit_veg_disease_model.keras")
print("✅ Model loaded successfully")
# Out:
# ✅ Model saved successfully as 'fruit_veg_disease_model.keras'
# ✅ Model loaded successfully
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 10 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import random
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# ✅ Load the trained model
model = load_model("fruit_veg_disease_model.keras")

# ✅ Define class names (filter out unwanted folders like .ipynb_checkpoints)
class_names = [d for d in os.listdir(train_path) 
               if os.path.isdir(os.path.join(train_path, d)) and not d.startswith('.')]

# ✅ Try random class until valid image found
img_found = False
attempts = 0
max_attempts = 10  # to prevent infinite loops

while not img_found and attempts < max_attempts:
    random_class = random.choice(class_names)
    class_dir = os.path.join(train_path, random_class)
    image_files = [f for f in os.listdir(class_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    if image_files:
        img_file = random.choice(image_files)
        img_path = os.path.join(class_dir, img_file)
        img_found = True
    attempts += 1

if not img_found:
    print("No valid image found in dataset.")
else:
    # ✅ Load and preprocess image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array / 255.0

    # ✅ Predict
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])
    predicted_class = class_names[predicted_class_index]

    # ✅ Show result
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Predicted: {predicted_class}")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam

# ✅ Paths to your dataset
base_dir = r"C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset"
train_path = os.path.join(base_dir, "train")
val_path = os.path.join(base_dir, "validation")

# ✅ Image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# ✅ Build CNN Model dynamically for all classes
model = Sequential([
    Input(shape=(224, 224, 3)),
    Conv2D(32, (3,3), activation='relu'), MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'), MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'), MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(train_generator.num_classes, activation='softmax')
])

# ✅ Compile model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# ✅ Train model
history = model.fit(
    train_generator,
    epochs=10,  # you can increase this for better accuracy
    validation_data=val_generator
)

# ✅ Save model
model.save("fruit_veg_disease_model.keras")
print("✅ Model trained and saved successfully!")
# Out:
# Found 7 images belonging to 2 classes.
# Found 7 images belonging to 2 classes.
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.8571 - loss: 0.6750 - val_accuracy: 1.0000 - val_loss: 1.7030e-07
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.7030e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# ...

# %%
import os
import shutil
import random

# Paths
source_dir = r'C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\dataset\Fruit And Vegetable Diseases Dataset'
destination_dir = r'C:\Users\JNTUK UCEK\OneDrive\Desktop\Smart Sorting\Fruit and Vegetable Diseases Dataset'

train_dir = os.path.join(destination_dir, 'train')
val_dir = os.path.join(destination_dir, 'validation')

# Create train and validation directories
for base_dir in [train_dir, val_dir]:
    os.makedirs(base_dir, exist_ok=True)

# Split ratio
split_ratio = 0.8

# Loop through all class folders
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)
    
    if os.path.isdir(class_path):
        images = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        random.shuffle(images)

        split_index = int(len(images) * split_ratio)
        train_images = images[:split_index]
        val_images = images[split_index:]

        # Create class subdirectories
        train_class_dir = os.path.join(train_dir, class_name)
        val_class_dir = os.path.join(val_dir, class_name)
        os.makedirs(train_class_dir, exist_ok=True)
        os.makedirs(val_class_dir, exist_ok=True)

        # Copy images to train folder
        for img in train_images:
            src = os.path.join(class_path, img)
            dst = os.path.join(train_class_dir, img)
            shutil.copy2(src, dst)

        # Copy images to validation folder
        for img in val_images:
            src = os.path.join(class_path, img)
            dst = os.path.join(val_class_dir, img)
            shutil.copy2(src, dst)

        print(f"✅ {class_name}: {len(train_images)} train, {len(val_images)} validation")

print("\n🎉 All classes split and copied successfully!")
# Out:
# ✅ Apple__Healthy: 1950 train, 488 validation
# ✅ Apple__Rotten: 2340 train, 585 validation
# ✅ Banana__Healthy: 1599 train, 400 validation
# ✅ Banana__Rotten: 2237 train, 560 validation
# ✅ Bellpepper__Healthy: 488 train, 123 validation
# ✅ Bellpepper__Rotten: 472 train, 119 validation
# ✅ Carrot__Healthy: 495 train, 124 validation
# ✅ Carrot__Rotten: 463 train, 116 validation
# ✅ Cucumber__Healthy: 486 train, 122 validation
# ✅ Cucumber__Rotten: 474 train, 119 validation
# ✅ Grape__Healthy: 160 train, 40 validation
# ✅ Grape__Rotten: 160 train, 40 validation
# ✅ Guava__Healthy: 160 train, 40 validation
# ✅ Guava__Rotten: 160 train, 40 validation
# ✅ Jujube__Healthy: 160 train, 40 validation
# ✅ Jujube__Rotten: 160 train, 40 validation
# ✅ Mango__Healthy: 1450 train, 363 validation
# ✅ Mango__Rotten: 1797 train, 450 validation
# ✅ Orange__Healthy: 1660 train, 415 validation
# ✅ Orange__Rotten: 1748 train, 438 validation
# ✅ Pomegranate__Healthy: 160 train, 40 validation
# ...

# %%
# Step 14: Import required libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import json

# Step 15: Set up paths
train_dir = r"C:\\Users\\JNTUK UCEK\\OneDrive\\Desktop\\Smart Sorting\\Fruit and Vegetable Diseases Dataset\\train"
val_dir = r"C:\\Users\\JNTUK UCEK\\OneDrive\\Desktop\\Smart Sorting\\Fruit and Vegetable Diseases Dataset\\validation"

# Step 16: Create data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Step 17: Build and compile the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Save class names
class_names = list(train_generator.class_indices.keys())
with open("class_names.json", "w") as f:
    json.dump(class_names, f)

# Train the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)

# Save the trained model
model.save("fruit_veg_disease_model.keras")
print("✅ Model trained and saved successfully!")
# Out:
# Found 23417 images belonging to 29 classes.
# Found 5867 images belonging to 29 classes.
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 301/732 ━━━━━━━━━━━━━━━━━━━━ 9:32 1s/step - accuracy: 0.2145 - loss: 2.7656
# ...
